# %% [markdown]
# # Uniform Motion

# %%
# %run -i 'run_model.py'
# Out:
# Initializing...
# Done
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /global/cscratch1/sd/roseyu/Eliza/UM/run_model.py in <module>
#      48
#      49     model.train()
# ---> 50     train_mse.append(train_epoch(train_loader, model, optimizer, loss_fun))
#      51     model.eval()
#      52     mse, _, _ = eval_epoch(valid_loader, model, loss_fun)
#
# /global/cscratch1/sd/roseyu/Eliza/UM/train.py in train_epoch(train_loader, model, optimizer, loss_function)
#      52         ims = []
#      53         for y in yy.transpose(0,1):
# ---> 54             im = model(xx)
#      55             xx = torch.cat([xx[:, 2:], im], 1)
#      56             loss += loss_function(im, y)
#
# ~/.conda/envs/myenv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
# ...
