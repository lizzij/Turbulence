# %% [markdown]
# ## Results

# %%
import torch
import matplotlib.pyplot as plt 
import numpy as np

img_direc = "/global/cscratch1/sd/roseyu/Eliza/Img"

# %%
idx = '1'

# %%
def show_result(eq, train, test):
    print("train: {}, test: {}".format(train, test))
    results = torch.load("../{}/results/Rot-UM-[{}-{}]{}.pt".format(eq, train, test, idx))
    print('test_mse', results['test_mse'])
    print('test_rmse', np.round(np.sqrt(results['test_mse']), 5))

    fig=plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.imshow(rot_results['trues'][0][0][0])
    plt.title("Target")
    plt.colorbar()
    plt.subplot(1, 2, 2)
    plt.imshow(rot_results['preds'][0][0][0])
    plt.title("Prediction")
    plt.colorbar()
    plt.show()
    fig.savefig(img_direc + '/{}-[{}-{}]{}'.format(eq, train, test, idx), bbox_inches='tight')

# %%
import os
for file in os.listdir('../Rot-UM/results'):
    print(file, os.stat(os.path.join('../Rot-UM/results', file)).st_size)
# Out:
# Rot-UM-[rot_um_92-rot_um_mag_92]1.pt 3786292885
# Rot-UM-[rot_um_92-mag_64]1.pt 1837692158
# Rot-UM-[rot_um_92-rot_92]1.pt 3455257577
# Rot-UM-[rot_um_92]1.pt 1860443309
# Rot-UM-[rot_um_92-scale_rot_um_182]1.pt 137
# Rot-UM-[rot_um_92-scale_128]1.pt 5963460683
# Rot-UM-[rot_um_92]1.pth 922238
# Rot-UM-[rot_um_92-um_64]1.pt 1847032901
# Rot-UM-[data_64]1.pth 922238
# Rot-UM-[rot_um_92-rot_um_92]1.pt 3780410668
# Rot-UM-[rot_um_92-data_64]1.pt 1860392239

# %%
show_result('Rot-UM', 'rot_um_92', 'scale_128')
# Out:
# train: rot_um_92, test: scale_128
# test_mse 0.04119
# test_rmse 0.20295

# %%
eqs = ['Rot-UM']  #['Rot-UM',  #'Rot-UM-Mag', 'Rot-UM-Scale']
train_sets = ['data_64']  #['data_64', 'rot_um_92', 'rot_um_mag_92', 'scale_rot_um_182']
test_sets = ['data_64', 'um_64',  'rot_92', 'mag_64', 'scale_128', 'rot_um_92', 'rot_um_mag_92'] # ['data_64', 'um_64',  'rot_92', 'mag_64', 'scale_128', 'rot_um_92', 'rot_um_mag_92', 'scale_rot_um_182']
for eq in eqs:
    for train in train_sets:
        for test in test_sets:
            show_result(eq, train, test)
# Out:
# train: data_64, test: data_64
# test_mse 0.07162
# test_rmse 0.26762
# train: data_64, test: um_64
# test_mse 0.07162
# test_rmse 0.26762
# train: data_64, test: rot_92
# test_mse 0.06845
# test_rmse 0.26163
# train: data_64, test: mag_64
# test_mse 0.10359
# test_rmse 0.32185
# train: data_64, test: scale_128
# test_mse 0.05863
# test_rmse 0.24214
# train: data_64, test: rot_um_92
# test_mse 0.06845
# test_rmse 0.26163
# train: data_64, test: rot_um_mag_92
# test_mse 0.08548
# test_rmse 0.29237
# train: data_64, test: scale_rot_um_182
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-59-17d9ee66c29e> in <module>
#       5     for train in train_sets:
#       6         for test in test_sets:
# ----> 7             show_result(eq, train, test)
#
# <ipython-input-37-be441a62dd1f> in show_result(eq, train, test)
#       1 def show_result(eq, train, test):
# ...
